# %% [markdown]
# # Machine Learning
# Cassady Jackson and Baylie Schnieder

# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns
from sklearn.model_selection import train_test_split
from sklearn.linear_model import LinearRegression
from sklearn.linear_model import LogisticRegression
from sklearn.neighbors import KNeighborsClassifier
from sklearn.tree import DecisionTreeClassifier
from sklearn.svm import SVC
from sklearn.metrics import confusion_matrix, classification_report, r2_score, f1_score
from scipy import stats
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns
import scipy.stats as stats
from scipy.stats import chi2_contingency
from scipy.stats import pearsonr

# %%
state_data = pd.read_csv('State_Unique_Data.csv')

# %%
state_data
# Out:
#        YearEnd LocationAbbr          State DataSource  \
# 0         2022           OH           Ohio      BRFSS
# 1         2022           WY        Wyoming      BRFSS
# 2         2022           AL        Alabama      BRFSS
# 3         2022           AL        Alabama      BRFSS
# 4         2022           AL        Alabama      BRFSS
# ...        ...          ...            ...        ...
# 29908     2022           WV  West Virginia      BRFSS
# 29909     2022           VT        Vermont      BRFSS
# 29910     2022           WV  West Virginia      BRFSS
# 29911     2022           WI      Wisconsin      BRFSS
# 29912     2022           WA     Washington      BRFSS
#
#                                        Topic  \
# 0                                 Disability
# 1            Cognitive Health and Caregiving
# 2                                     Asthma
# 3                              Mental Health
# 4                                Oral Health
# ...                                      ...
# 29908                          Mental Health
# 29909                                  Sleep
# 29910  Chronic Obstructive Pulmonary Disease
# 29911                           Immunization
# 29912                                Alcohol
#
#                                                 Question DataValueUnit  \
# 0                             Adults with any disability             %
# 1      Provided care for someone with dementia or oth...             %
# 2                            Current asthma among adults             %
# 3                  Frequent mental distress among adults             %
# 4            No teeth lost among adults aged 18-64 years             %
# ...                                                  ...           ...
# 29908              Frequent mental distress among adults             %
# 29909                  Short sleep duration among adults             %
# 29910  Chronic obstructive pulmonary disease among ad...             %
# 29911  Pneumococcal vaccination among adults aged 65 ...             %
# 29912             Binge drinking prevalence among adults             %
#
#                  DataValueType  DataValue  DataValueAlt  ...  \
# 0      Age-adjusted Prevalence       42.8          42.8  ...
# 1             Crude Prevalence       21.5          21.5  ...
# 2      Age-adjusted Prevalence        7.4           7.4  ...
# 3             Crude Prevalence       15.0          15.0  ...
# 4             Crude Prevalence       42.7          42.7  ...
# ...                        ...        ...           ...  ...
# 29908  Age-adjusted Prevalence       26.0          26.0  ...
# 29909         Crude Prevalence       26.5          26.5  ...
# 29910         Crude Prevalence       14.0          14.0  ...
# 29911         Crude Prevalence       64.2          64.2  ...
# 29912  Age-adjusted Prevalence       19.2          19.2  ...
#
#                  Stratification1  LocationID TopicID QuestionID  \
# 0      Multiracial, non-Hispanic          39     DIS      DIS01
# 1                      Age 45-64          56     CHC      CHC03
# 2                           Male           1     AST      AST02
# 3                           Male           1     MEN      MEN05
# 4                      Age 45-64           1     ORH      ORH01
# ...                          ...         ...     ...        ...
# 29908                     Female          54     MEN      MEN05
# 29909        Asian, non-Hispanic          50    SLEP      SLP03
# 29910                    Overall          54    COPD     COPD01
# 29911        Black, non-Hispanic          55     IMM      IMM04
# 29912                       Male          53     ALC      ALC06
#
#        DataValueTypeID StratificationCategoryID1 StratificationID1  \
# 0           AGEADJPREV                      RACE               MRC
# 1              CRDPREV                       AGE           AGE4564
# 2           AGEADJPREV                       SEX              SEXM
# 3              CRDPREV                       SEX              SEXM
# 4              CRDPREV                       AGE           AGE4564
# ...                ...                       ...               ...
# 29908       AGEADJPREV                       SEX              SEXF
# 29909          CRDPREV                      RACE               ASN
# 29910          CRDPREV                   OVERALL               OVR
# 29911          CRDPREV                      RACE               BLK
# 29912       AGEADJPREV                       SEX              SEXM
#
#       Overall Public School Rank 2022 Higher Ed Quality 2022  \
# 0                                  32                     33
# 1                                  19                     18
# 2                                  44                     46
# 3                                  44                     46
# 4                                  44                     46
# ...                               ...                    ...
# 29908                              39                     45
# 29909                               5                      8
# 29910                              39                     45
# 29911                               8                      5
# 29912                              21                     26
#
#       School Safety Rank 2022
# 0                          39
# 1                          29
# 2                          17
# 3                          17
# 4                          17
# ...                       ...
# 29908                       7
# 29909                       4
# 29910                       7
# 29911                      24
# 29912                       5
#
# [29913 rows x 23 columns]

# %%
dummies2 = pd.get_dummies(state_data['Topic'])

states_data = pd.concat([state_data, dummies2], axis=1)
states_data.drop(['StratificationID1','StratificationCategoryID1','DataValueTypeID','QuestionID', 'TopicID', 'StratificationCategory1', 'DataValueType', 'DataValueUnit', 'Question','DataSource', 'LocationID', 'Stratification1', 'LocationAbbr', 'State', 'Topic', 'YearEnd', 'Higher Ed Quality 2022', 'School Safety Rank 2022', 'DataValue', 'DataValueAlt', 'LowConfidenceLimit', 'HighConfidenceLimit' ], axis=1, inplace=True)
display(states_data)
# Out:
#        Overall Public School Rank 2022  Alcohol  Arthritis  Asthma  Cancer  \
# 0                                   32    False      False   False   False
# 1                                   19    False      False   False   False
# 2                                   44    False      False    True   False
# 3                                   44    False      False   False   False
# 4                                   44    False      False   False   False
# ...                                ...      ...        ...     ...     ...
# 29908                               39    False      False   False   False
# 29909                                5    False      False   False   False
# 29910                               39    False      False   False   False
# 29911                                8    False      False   False   False
# 29912                               21     True      False   False   False
#
#        Chronic Obstructive Pulmonary Disease  Cognitive Health and Caregiving  \
# 0                                      False                            False
# 1                                      False                             True
# 2                                      False                            False
# 3                                      False                            False
# 4                                      False                            False
# ...                                      ...                              ...
# 29908                                  False                            False
# 29909                                  False                            False
# 29910                                   True                            False
# 29911                                  False                            False
# 29912                                  False                            False
#
#        Diabetes  Disability  Health Status  Immunization  Mental Health  \
# 0         False        True          False         False          False
# 1         False       False          False         False          False
# 2         False       False          False         False          False
# 3         False       False          False         False           True
# 4         False       False          False         False          False
# ...         ...         ...            ...           ...            ...
# 29908     False       False          False         False           True
# 29909     False       False          False         False          False
# 29910     False       False          False         False          False
# 29911     False       False          False          True          False
# 29912     False       False          False         False          False
#
#        Nutrition, Physical Activity, and Weight Status  Oral Health  Sleep  \
# 0                                                False        False  False
# 1                                                False        False  False
# 2                                                False        False  False
# 3                                                False        False  False
# 4                                                False         True  False
# ...                                                ...          ...    ...
# 29908                                            False        False  False
# 29909                                            False        False   True
# 29910                                            False        False  False
# 29911                                            False        False  False
# 29912                                            False        False  False
#
#        Social Determinants of Health  Tobacco
# 0                              False    False
# 1                              False    False
# 2                              False    False
# 3                              False    False
# 4                              False    False
# ...                              ...      ...
# 29908                          False    False
# 29909                          False    False
# 29910                          False    False
# 29911                          False    False
# 29912                          False    False
#
# [29913 rows x 17 columns]

# %% [markdown]
# ### Grouping by Top 10 State Rankings and Bottom 10 State Rankings

# %%
def top_ten(state):
    if state <= 10:
        return 'Top 10'
    elif 10 < state <= 41:
        return 'Middle'
    else:
        return 'Bottom 10'

state_data['Ranking Level'] = state_data['Overall Public School Rank 2022'].apply(top_ten)

display(state_data)
# Out:
#        YearEnd LocationAbbr          State DataSource  \
# 0         2022           OH           Ohio      BRFSS
# 1         2022           WY        Wyoming      BRFSS
# 2         2022           AL        Alabama      BRFSS
# 3         2022           AL        Alabama      BRFSS
# 4         2022           AL        Alabama      BRFSS
# ...        ...          ...            ...        ...
# 29908     2022           WV  West Virginia      BRFSS
# 29909     2022           VT        Vermont      BRFSS
# 29910     2022           WV  West Virginia      BRFSS
# 29911     2022           WI      Wisconsin      BRFSS
# 29912     2022           WA     Washington      BRFSS
#
#                                        Topic  \
# 0                                 Disability
# 1            Cognitive Health and Caregiving
# 2                                     Asthma
# 3                              Mental Health
# 4                                Oral Health
# ...                                      ...
# 29908                          Mental Health
# 29909                                  Sleep
# 29910  Chronic Obstructive Pulmonary Disease
# 29911                           Immunization
# 29912                                Alcohol
#
#                                                 Question DataValueUnit  \
# 0                             Adults with any disability             %
# 1      Provided care for someone with dementia or oth...             %
# 2                            Current asthma among adults             %
# 3                  Frequent mental distress among adults             %
# 4            No teeth lost among adults aged 18-64 years             %
# ...                                                  ...           ...
# 29908              Frequent mental distress among adults             %
# 29909                  Short sleep duration among adults             %
# 29910  Chronic obstructive pulmonary disease among ad...             %
# 29911  Pneumococcal vaccination among adults aged 65 ...             %
# 29912             Binge drinking prevalence among adults             %
#
#                  DataValueType  DataValue  DataValueAlt  ...  LocationID  \
# 0      Age-adjusted Prevalence       42.8          42.8  ...          39
# 1             Crude Prevalence       21.5          21.5  ...          56
# 2      Age-adjusted Prevalence        7.4           7.4  ...           1
# 3             Crude Prevalence       15.0          15.0  ...           1
# 4             Crude Prevalence       42.7          42.7  ...           1
# ...                        ...        ...           ...  ...         ...
# 29908  Age-adjusted Prevalence       26.0          26.0  ...          54
# 29909         Crude Prevalence       26.5          26.5  ...          50
# 29910         Crude Prevalence       14.0          14.0  ...          54
# 29911         Crude Prevalence       64.2          64.2  ...          55
# 29912  Age-adjusted Prevalence       19.2          19.2  ...          53
#
#        TopicID QuestionID DataValueTypeID  StratificationCategoryID1  \
# 0          DIS      DIS01      AGEADJPREV                       RACE
# 1          CHC      CHC03         CRDPREV                        AGE
# 2          AST      AST02      AGEADJPREV                        SEX
# 3          MEN      MEN05         CRDPREV                        SEX
# 4          ORH      ORH01         CRDPREV                        AGE
# ...        ...        ...             ...                        ...
# 29908      MEN      MEN05      AGEADJPREV                        SEX
# 29909     SLEP      SLP03         CRDPREV                       RACE
# 29910     COPD     COPD01         CRDPREV                    OVERALL
# 29911      IMM      IMM04         CRDPREV                       RACE
# 29912      ALC      ALC06      AGEADJPREV                        SEX
#
#       StratificationID1 Overall Public School Rank 2022  \
# 0                   MRC                              32
# 1               AGE4564                              19
# 2                  SEXM                              44
# 3                  SEXM                              44
# 4               AGE4564                              44
# ...                 ...                             ...
# 29908              SEXF                              39
# 29909               ASN                               5
# 29910               OVR                              39
# 29911               BLK                               8
# 29912              SEXM                              21
#
#       Higher Ed Quality 2022 School Safety Rank 2022 Ranking Level
# 0                         33                      39        Middle
# 1                         18                      29        Middle
# 2                         46                      17     Bottom 10
# 3                         46                      17     Bottom 10
# 4                         46                      17     Bottom 10
# ...                      ...                     ...           ...
# 29908                     45                       7        Middle
# 29909                      8                       4        Top 10
# 29910                     45                       7        Middle
# 29911                      5                      24        Top 10
# 29912                     26                       5        Middle
#
# [29913 rows x 24 columns]

# %%
top_ten = state_data.copy()
bottom_ten = state_data.copy()

# %%
top_ten = top_ten.drop(top_ten[top_ten['Ranking Level'] != 'Top 10'].index)
display(top_ten)
top_ten.to_csv('TopTenStates.csv', header=True, index=False, encoding="utf-8")
# Out:
#        YearEnd LocationAbbr        State DataSource  \
# 23        2022           CT  Connecticut      BRFSS
# 24        2022           CT  Connecticut      BRFSS
# 25        2022           CT  Connecticut      BRFSS
# 26        2022           DE     Delaware      BRFSS
# 27        2022           DE     Delaware      BRFSS
# ...        ...          ...          ...        ...
# 29904     2022           WI    Wisconsin      BRFSS
# 29905     2022           VA     Virginia      BRFSS
# 29907     2022           VA     Virginia      BRFSS
# 29909     2022           VT      Vermont      BRFSS
# 29911     2022           WI    Wisconsin      BRFSS
#
#                                                  Topic  \
# 23                                       Health Status
# 24                                        Immunization
# 25     Nutrition, Physical Activity, and Weight Status
# 26                                          Disability
# 27                                         Oral Health
# ...                                                ...
# 29904                                    Health Status
# 29905                                    Health Status
# 29907                                          Tobacco
# 29909                                            Sleep
# 29911                                     Immunization
#
#                                                 Question DataValueUnit  \
# 23               Recent activity limitation among adults        Number
# 24     Influenza vaccination among adults 18â€“64 who...             %
# 25                                  Obesity among adults             %
# 26                            Adults with any disability             %
# 27     Six or more teeth lost among adults aged 65 ye...             %
# ...                                                  ...           ...
# 29904  Fair or poor self-rated health status among ad...             %
# 29905            Frequent physical distress among adults             %
# 29907             Current cigarette smoking among adults             %
# 29909                  Short sleep duration among adults             %
# 29911  Pneumococcal vaccination among adults aged 65 ...             %
#
#                  DataValueType  DataValue  DataValueAlt  ...  LocationID  \
# 23                  Crude Mean        2.9           2.9  ...           9
# 24            Crude Prevalence       49.3          49.3  ...           9
# 25            Crude Prevalence       28.6          28.6  ...           9
# 26            Crude Prevalence       24.5          24.5  ...          10
# 27     Age-adjusted Prevalence       32.0          32.0  ...          10
# ...                        ...        ...           ...  ...         ...
# 29904  Age-adjusted Prevalence       17.4          17.4  ...          55
# 29905  Age-adjusted Prevalence       12.2          12.2  ...          51
# 29907  Age-adjusted Prevalence       12.3          12.3  ...          51
# 29909         Crude Prevalence       26.5          26.5  ...          50
# 29911         Crude Prevalence       64.2          64.2  ...          55
#
#        TopicID QuestionID DataValueTypeID  StratificationCategoryID1  \
# 23         HEA      HEA04         CRDMEAN                    OVERALL
# 24         IMM      IMM02         CRDPREV                        SEX
# 25        NPAW      NPW14         CRDPREV                        AGE
# 26         DIS      DIS01         CRDPREV                        SEX
# 27         ORH      ORH02      AGEADJPREV                        SEX
# ...        ...        ...             ...                        ...
# 29904      HEA      HEA01      AGEADJPREV                       RACE
# 29905      HEA      HEA03      AGEADJPREV                       RACE
# 29907      TOB      TOB04      AGEADJPREV                    OVERALL
# 29909     SLEP      SLP03         CRDPREV                       RACE
# 29911      IMM      IMM04         CRDPREV                       RACE
#
#       StratificationID1 Overall Public School Rank 2022  \
# 23                  OVR                               2
# 24                 SEXM                               2
# 25               AGE65P                               2
# 26                 SEXM                               9
# 27                 SEXM                               9
# ...                 ...                             ...
# 29904              AIAN                               8
# 29905               WHT                               4
# 29907               OVR                               4
# 29909               ASN                               5
# 29911               BLK                               8
#
#       Higher Ed Quality 2022 School Safety Rank 2022 Ranking Level
# 23                         2                      19        Top 10
# 24                         2                      19        Top 10
# 25                         2                      19        Top 10
# 26                        15                       2        Top 10
# 27                        15                       2        Top 10
# ...                      ...                     ...           ...
# 29904                      5                      24        Top 10
# 29905                      4                       3        Top 10
# 29907                      4                       3        Top 10
# 29909                      8                       4        Top 10
# 29911                      5                      24        Top 10
#
# [6148 rows x 24 columns]

# %%
bottom_ten = bottom_ten.drop(bottom_ten[bottom_ten['Ranking Level'] != 'Bottom 10'].index)
display(bottom_ten)
bottom_ten.to_csv('BottomTen.csv', header=True, index=False, encoding="utf-8")
# Out:
#        YearEnd LocationAbbr           State DataSource  \
# 2         2022           AL         Alabama      BRFSS
# 3         2022           AL         Alabama      BRFSS
# 4         2022           AL         Alabama      BRFSS
# 5         2022           AL         Alabama      BRFSS
# 6         2022           AL         Alabama      BRFSS
# ...        ...          ...             ...        ...
# 26337     2022           SC  South Carolina      BRFSS
# 26342     2022           OK        Oklahoma      BRFSS
# 26346     2022           OK        Oklahoma      BRFSS
# 26353     2022           SC  South Carolina      BRFSS
# 26363     2022           OK        Oklahoma      BRFSS
#
#                                                  Topic  \
# 2                                               Asthma
# 3                                        Mental Health
# 4                                          Oral Health
# 5                                          Oral Health
# 6                                              Tobacco
# ...                                                ...
# 26337                                    Health Status
# 26342                                          Alcohol
# 26346                                     Immunization
# 26353  Nutrition, Physical Activity, and Weight Status
# 26363                                      Oral Health
#
#                                                 Question DataValueUnit  \
# 2                            Current asthma among adults             %
# 3                  Frequent mental distress among adults             %
# 4            No teeth lost among adults aged 18-64 years             %
# 5      Visited dentist or dental clinic in the past y...             %
# 6                 Current cigarette smoking among adults             %
# ...                                                  ...           ...
# 26337  Average recent physically unhealthy days among...        Number
# 26342  Binge drinking intensity among adults who bing...        Number
# 26346  Pneumococcal vaccination among adults aged 18â...             %
# 26353     No leisure-time physical activity among adults             %
# 26363        No teeth lost among adults aged 18-64 years             %
#
#                  DataValueType  DataValue  DataValueAlt  ...  LocationID  \
# 2      Age-adjusted Prevalence        7.4           7.4  ...           1
# 3             Crude Prevalence       15.0          15.0  ...           1
# 4             Crude Prevalence       42.7          42.7  ...           1
# 5             Crude Prevalence       59.7          59.7  ...           1
# 6      Age-adjusted Prevalence       37.6          37.6  ...           1
# ...                        ...        ...           ...  ...         ...
# 26337        Age-adjusted Mean        3.8           3.8  ...          45
# 26342             Crude Median        6.5           6.5  ...          40
# 26346         Crude Prevalence       40.1          40.1  ...          40
# 26353  Age-adjusted Prevalence       28.3          28.3  ...          45
# 26363         Crude Prevalence       70.3          70.3  ...          40
#
#        TopicID QuestionID DataValueTypeID  StratificationCategoryID1  \
# 2          AST      AST02      AGEADJPREV                        SEX
# 3          MEN      MEN05         CRDPREV                        SEX
# 4          ORH      ORH01         CRDPREV                        AGE
# 5          ORH      ORH06         CRDPREV                       RACE
# 6          TOB      TOB04      AGEADJPREV                       RACE
# ...        ...        ...             ...                        ...
# 26337      HEA      HEA02      AGEADJMEAN                    OVERALL
# 26342      ALC      ALC05         CRDMEDN                        SEX
# 26346      IMM      IMM03         CRDPREV                        AGE
# 26353     NPAW      NPW06      AGEADJPREV                        SEX
# 26363      ORH      ORH01         CRDPREV                        AGE
#
#       StratificationID1 Overall Public School Rank 2022  \
# 2                  SEXM                              44
# 3                  SEXM                              44
# 4               AGE4564                              44
# 5                   WHT                              44
# 6                   MRC                              44
# ...                 ...                             ...
# 26337               OVR                              43
# 26342              SEXM                              47
# 26346           AGE4564                              47
# 26353              SEXF                              43
# 26363           AGE1844                              47
#
#       Higher Ed Quality 2022 School Safety Rank 2022 Ranking Level
# 2                         46                      17     Bottom 10
# 3                         46                      17     Bottom 10
# 4                         46                      17     Bottom 10
# 5                         46                      17     Bottom 10
# 6                         46                      17     Bottom 10
# ...                      ...                     ...           ...
# 26337                     42                      41     Bottom 10
# 26342                     48                      20     Bottom 10
# 26346                     48                      20     Bottom 10
# 26353                     42                      41     Bottom 10
# 26363                     48                      20     Bottom 10
#
# [5912 rows x 24 columns]

# %% [markdown]
# ### Pearson Correlation

# %% [markdown]
# Used to understand the strength and direction of the linear relationship between two variables.

# %%
# calculate Pearson correlation between 'Bottom 10' Ranking and DataValueUnit (instances of chronic illness) 
pearson_corr = bottom_ten["Overall Public School Rank 2022"].corr(bottom_ten["DataValue"], method="pearson")

# display the result
print(f"Pearson Correlation: {pearson_corr:.4f}")

# interpretation
if abs(pearson_corr) < 0.3:
    print("Interpretation: No or weak linear correlation.")
elif 0.3 <= abs(pearson_corr) < 0.7:
    print("Interpretation: Moderate linear correlation.")
else:
    print("Interpretation: Strong linear correlation.")
# Out:
# Pearson Correlation: -0.0253
# Interpretation: No or weak linear correlation.

# %% [markdown]
# Used to test the hypothesis found in the Pearson correlation and understand if it is significant or could have occured by chance

# %%
# perform the Pearson correlation test
corr_stat, p_value = pearsonr(bottom_ten["Overall Public School Rank 2022"], bottom_ten["DataValue"])

# display the correlation statistic and p-value
print(f"Pearson Correlation Coefficient: {corr_stat:.4f}")
print(f"P-value: {p_value:.4f}")

# interpretation based on p-value
alpha = 0.05  # significance level

if p_value > alpha:
    print("Fail to reject H0: No significant correlation (correlation = 0).")
else:
    print("Reject H0: Significant correlation exists (correlation != 0).")
# Out:
# Pearson Correlation Coefficient: -0.0253
# P-value: 0.0521
# Fail to reject H0: No significant correlation (correlation = 0).

# %%
# calculate Pearson correlation between 'Bottom 10' Ranking and DataValueUnit (instances of chronic illness) 
top_pearson_corr = top_ten["Overall Public School Rank 2022"].corr(top_ten["DataValue"], method="pearson")

# display the result
print(f"Pearson Correlation: {top_pearson_corr:.4f}")

# interpretation
if abs(top_pearson_corr) < 0.3:
    print("Interpretation: No or weak linear correlation.")
elif 0.3 <= abs(top_pearson_corr) < 0.7:
    print("Interpretation: Moderate linear correlation.")
else:
    print("Interpretation: Strong linear correlation.")
# Out:
# Pearson Correlation: 0.0058
# Interpretation: No or weak linear correlation.

# %%
# perform the Pearson correlation test
corr_stat, p_value = pearsonr(top_ten["Overall Public School Rank 2022"], top_ten["DataValue"])

# display the correlation statistic and p-value
print(f"Pearson Correlation Coefficient: {corr_stat:.4f}")
print(f"P-value: {p_value:.4f}")

# interpretation based on p-value
alpha = 0.05  # significance level

if p_value > alpha:
    print("Fail to reject H0: No significant correlation (correlation = 0).")
else:
    print("Reject H0: Significant correlation exists (correlation != 0).")
# Out:
# Pearson Correlation Coefficient: 0.0058
# P-value: 0.6476
# Fail to reject H0: No significant correlation (correlation = 0).

# %%
state_data
# Out:
#        YearEnd LocationAbbr          State DataSource  \
# 0         2022           OH           Ohio      BRFSS
# 1         2022           WY        Wyoming      BRFSS
# 2         2022           AL        Alabama      BRFSS
# 3         2022           AL        Alabama      BRFSS
# 4         2022           AL        Alabama      BRFSS
# ...        ...          ...            ...        ...
# 29908     2022           WV  West Virginia      BRFSS
# 29909     2022           VT        Vermont      BRFSS
# 29910     2022           WV  West Virginia      BRFSS
# 29911     2022           WI      Wisconsin      BRFSS
# 29912     2022           WA     Washington      BRFSS
#
#                                        Topic  \
# 0                                 Disability
# 1            Cognitive Health and Caregiving
# 2                                     Asthma
# 3                              Mental Health
# 4                                Oral Health
# ...                                      ...
# 29908                          Mental Health
# 29909                                  Sleep
# 29910  Chronic Obstructive Pulmonary Disease
# 29911                           Immunization
# 29912                                Alcohol
#
#                                                 Question DataValueUnit  \
# 0                             Adults with any disability             %
# 1      Provided care for someone with dementia or oth...             %
# 2                            Current asthma among adults             %
# 3                  Frequent mental distress among adults             %
# 4            No teeth lost among adults aged 18-64 years             %
# ...                                                  ...           ...
# 29908              Frequent mental distress among adults             %
# 29909                  Short sleep duration among adults             %
# 29910  Chronic obstructive pulmonary disease among ad...             %
# 29911  Pneumococcal vaccination among adults aged 65 ...             %
# 29912             Binge drinking prevalence among adults             %
#
#                  DataValueType  DataValue  DataValueAlt  ...  LocationID  \
# 0      Age-adjusted Prevalence       42.8          42.8  ...          39
# 1             Crude Prevalence       21.5          21.5  ...          56
# 2      Age-adjusted Prevalence        7.4           7.4  ...           1
# 3             Crude Prevalence       15.0          15.0  ...           1
# 4             Crude Prevalence       42.7          42.7  ...           1
# ...                        ...        ...           ...  ...         ...
# 29908  Age-adjusted Prevalence       26.0          26.0  ...          54
# 29909         Crude Prevalence       26.5          26.5  ...          50
# 29910         Crude Prevalence       14.0          14.0  ...          54
# 29911         Crude Prevalence       64.2          64.2  ...          55
# 29912  Age-adjusted Prevalence       19.2          19.2  ...          53
#
#        TopicID QuestionID DataValueTypeID  StratificationCategoryID1  \
# 0          DIS      DIS01      AGEADJPREV                       RACE
# 1          CHC      CHC03         CRDPREV                        AGE
# 2          AST      AST02      AGEADJPREV                        SEX
# 3          MEN      MEN05         CRDPREV                        SEX
# 4          ORH      ORH01         CRDPREV                        AGE
# ...        ...        ...             ...                        ...
# 29908      MEN      MEN05      AGEADJPREV                        SEX
# 29909     SLEP      SLP03         CRDPREV                       RACE
# 29910     COPD     COPD01         CRDPREV                    OVERALL
# 29911      IMM      IMM04         CRDPREV                       RACE
# 29912      ALC      ALC06      AGEADJPREV                        SEX
#
#       StratificationID1 Overall Public School Rank 2022  \
# 0                   MRC                              32
# 1               AGE4564                              19
# 2                  SEXM                              44
# 3                  SEXM                              44
# 4               AGE4564                              44
# ...                 ...                             ...
# 29908              SEXF                              39
# 29909               ASN                               5
# 29910               OVR                              39
# 29911               BLK                               8
# 29912              SEXM                              21
#
#       Higher Ed Quality 2022 School Safety Rank 2022 Ranking Level
# 0                         33                      39        Middle
# 1                         18                      29        Middle
# 2                         46                      17     Bottom 10
# 3                         46                      17     Bottom 10
# 4                         46                      17     Bottom 10
# ...                      ...                     ...           ...
# 29908                     45                       7        Middle
# 29909                      8                       4        Top 10
# 29910                     45                       7        Middle
# 29911                      5                      24        Top 10
# 29912                     26                       5        Middle
#
# [29913 rows x 24 columns]

# %%
states_data
# Out:
#        Overall Public School Rank 2022  Alcohol  Arthritis  Asthma  Cancer  \
# 0                                   32    False      False   False   False
# 1                                   19    False      False   False   False
# 2                                   44    False      False    True   False
# 3                                   44    False      False   False   False
# 4                                   44    False      False   False   False
# ...                                ...      ...        ...     ...     ...
# 29908                               39    False      False   False   False
# 29909                                5    False      False   False   False
# 29910                               39    False      False   False   False
# 29911                                8    False      False   False   False
# 29912                               21     True      False   False   False
#
#        Chronic Obstructive Pulmonary Disease  Cognitive Health and Caregiving  \
# 0                                      False                            False
# 1                                      False                             True
# 2                                      False                            False
# 3                                      False                            False
# 4                                      False                            False
# ...                                      ...                              ...
# 29908                                  False                            False
# 29909                                  False                            False
# 29910                                   True                            False
# 29911                                  False                            False
# 29912                                  False                            False
#
#        Diabetes  Disability  Health Status  Immunization  Mental Health  \
# 0         False        True          False         False          False
# 1         False       False          False         False          False
# 2         False       False          False         False          False
# 3         False       False          False         False           True
# 4         False       False          False         False          False
# ...         ...         ...            ...           ...            ...
# 29908     False       False          False         False           True
# 29909     False       False          False         False          False
# 29910     False       False          False         False          False
# 29911     False       False          False          True          False
# 29912     False       False          False         False          False
#
#        Nutrition, Physical Activity, and Weight Status  Oral Health  Sleep  \
# 0                                                False        False  False
# 1                                                False        False  False
# 2                                                False        False  False
# 3                                                False        False  False
# 4                                                False         True  False
# ...                                                ...          ...    ...
# 29908                                            False        False  False
# 29909                                            False        False   True
# 29910                                            False        False  False
# 29911                                            False        False  False
# 29912                                            False        False  False
#
#        Social Determinants of Health  Tobacco
# 0                              False    False
# 1                              False    False
# 2                              False    False
# 3                              False    False
# 4                              False    False
# ...                              ...      ...
# 29908                          False    False
# 29909                          False    False
# 29910                          False    False
# 29911                          False    False
# 29912                          False    False
#
# [29913 rows x 17 columns]

# %%
XKNN = states_data.drop('Overall Public School Rank 2022', axis=1)
yKNN = states_data['Overall Public School Rank 2022'].values
XKNN_train, XKNN_test, yKNN_train, yKNN_test = train_test_split(XKNN ,yKNN, test_size = 0.2, random_state = 42)
knn = KNeighborsClassifier(n_neighbors =7)
knn.fit(XKNN_train, yKNN_train)
yKNN_pred = knn.predict(XKNN_test)
print(confusion_matrix(yKNN_test, yKNN_pred))
# Out:
# [[29  2  6 ... 18  0  0]
#  [31  6  4 ... 15  0  0]
#  [30  2  4 ... 13  0  0]
#  ...
#  [34  4  3 ... 18  0  0]
#  [31  5  4 ...  0  0  0]
#  [37  1  5 ... 13  0  0]]

# %%
print(classification_report(yKNN_test, yKNN_pred))
# Out:
#               precision    recall  f1-score   support
#
#            1       0.02      0.22      0.04       134
#            2       0.04      0.04      0.04       145
#            3       0.02      0.03      0.02       120
#            4       0.00      0.00      0.00       106
#            5       0.02      0.06      0.03       114
#            6       0.00      0.00      0.00        90
#            7       0.03      0.03      0.03       147
#            8       0.02      0.03      0.02       127
#            9       0.00      0.00      0.00       118
#           10       0.02      0.03      0.02       119
#           11       0.01      0.07      0.02        96
#           12       0.00      0.00      0.00       133
#           13       0.00      0.00      0.00       105
#           14       0.02      0.09      0.03        81
#           15       0.00      0.00      0.00       133
#           16       0.00      0.00      0.00        98
#           17       0.02      0.08      0.03       119
#           18       0.01      0.02      0.01       116
#           19       0.00      0.00      0.00       107
#           20       0.00      0.00      0.00       132
#           21       0.00      0.00      0.00       137
#           22       0.00      0.00      0.00       134
#           23       0.02      0.03      0.03       124
#           24       0.00      0.00      0.00       105
#           25       0.00      0.00      0.00        87
#           26       0.00      0.00      0.00       119
#           27       0.00      0.00      0.00       116
#           28       0.00      0.00      0.00       141
#           29       0.00      0.00      0.00       127
#           30       0.00      0.00      0.00       127
#           31       0.00      0.00      0.00       128
#           32       0.00      0.00      0.00       116
#           33       0.00      0.00      0.00       105
#           34       0.00      0.00      0.00       131
#           35       0.00      0.00      0.00       112
#           36       0.00      0.00      0.00       162
#           37       0.00      0.00      0.00       156
#           38       0.01      0.07      0.02       112
#           39       0.00      0.00      0.00        86
#           40       0.00      0.00      0.00       105
#           42       0.00      0.00      0.00       111
#           43       0.00      0.00      0.00       145
#           44       0.00      0.00      0.00       102
#           45       0.00      0.00      0.00       123
#           46       0.00      0.00      0.00       115
#           47       0.00      0.00      0.00       120
#           48       0.00      0.00      0.00       129
#           49       0.03      0.13      0.05       135
#           50       0.00      0.00      0.00       115
#           51       0.00      0.00      0.00       118
#
#     accuracy                           0.02      5983
#    macro avg       0.01      0.02      0.01      5983
# weighted avg       0.01      0.02      0.01      5983
# C:\ProgramData\anaconda3\Lib\site-packages\sklearn\metrics\_classification.py:1531: UndefinedMetricWarning: Precision is ill-defined and being set to 0.0 in labels with no predicted samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, f"{metric.capitalize()} is", len(result))
# C:\ProgramData\anaconda3\Lib\site-packages\sklearn\metrics\_classification.py:1531: UndefinedMetricWarning: Precision is ill-defined and being set to 0.0 in labels with no predicted samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, f"{metric.capitalize()} is", len(result))
# C:\ProgramData\anaconda3\Lib\site-packages\sklearn\metrics\_classification.py:1531: UndefinedMetricWarning: Precision is ill-defined and being set to 0.0 in labels with no predicted samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, f"{metric.capitalize()} is", len(result))

# %%
f1_score(yKNN_test, yKNN_pred, average= 'weighted')
# Out:
# 0.008198359079552893
